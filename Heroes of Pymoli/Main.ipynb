# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import os
import pandas as pd

#print(os.getcwd())
os.chdir("/Users/ashleygates/Pandas-Challenge/Heroes of Pymoli")

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

purchase_data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# 4                                         Fury   1.44
# ..                                         ...    ...
# 775                                       Wolf   3.54
# 776                           Exiled Doomblade   1.63
# 777      Celeste, Incarnation of the Corrupted   3.46
# 778                               Final Critic   4.19
# 779                                       Dawn   4.60
#
# [780 rows x 7 columns]

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
purchase_data.count
# Out:
# <bound method DataFrame.count of      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# 4                                         Fury   1.44
# ..                                         ...    ...
# 775                                       Wolf   3.54
# 776                           Exiled Doomblade   1.63
# 777      Celeste, Incarnation of the Corrupted   3.46
# 778                               Final Critic   4.19
# 779                                       Dawn   4.60
#
# [780 rows x 7 columns]>

# %%
no_null_purchase_data = purchase_data.dropna(how='any')

# %%
no_null_purchase_data.count()
# Out:
# Purchase ID    780
# SN             780
# Age            780
# Gender         780
# Item ID        780
# Item Name      780
# Price          780
# dtype: int64

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Count of unique items
unique_items = len(pd.unique(purchase_data['Item Name']))
print("No.of.unique values :", 
      unique_items)
# Out:
# No.of.unique values : 179

# %%
#Average purchase price
average_price=purchase_data["Price"].mean()
print(average_price)
# Out:
# 3.050987179487176

# %%
#Total number of purchases
item_total = purchase_data["Item Name"].count()
print(item_total)
# Out:
# 780

# %%
#Total sum of purchased items (Total Revenue)
item_sum = purchase_data["Price"].sum()
print(item_sum)
# Out:
# 2379.77

# %%
#Print purchasing analysis data frame
summary_df = pd.DataFrame({"Number of Unique Items": [unique_items],
                           "Average Item Price": [average_price],
                           "Total Number of Items":[item_total],
                           "Total Revenue": [item_sum],
                           })

summary_df
# Out:
#    Number of Unique Items  Average Item Price  Total Number of Items  \
# 0                     179            3.050987                    780
#
#    Total Revenue
# 0        2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
sn_duplicate_df = purchase_data.drop_duplicates(subset=['SN'])
sn_duplicate_df.head(10)
# Out:
#    Purchase ID             SN  Age                 Gender  Item ID  \
# 0            0        Lisim78   20                   Male      108
# 1            1    Lisovynya38   40                   Male      143
# 2            2     Ithergue48   24                   Male       92
# 3            3  Chamassasya86   24                   Male      100
# 4            4      Iskosia90   23                   Male      131
# 5            5        Yalae81   22                   Male       81
# 6            6      Itheria73   36                   Male      169
# 7            7    Iskjaskst81   20                   Male      162
# 8            8      Undjask33   22                   Male       21
# 9            9    Chanosian48   35  Other / Non-Disclosed      136
#
#                                    Item Name  Price Age Group
# 0  Extraction, Quickblade Of Trembling Hands   3.53     10-19
# 1                          Frenzied Scimitar   1.56     30-39
# 2                               Final Critic   4.88     20-29
# 3                                Blindscythe   3.27     20-29
# 4                                       Fury   1.44     20-29
# 5                                  Dreamkiss   3.61     20-29
# 6     Interrogator, Blood Blade of the Queen   2.18     30-39
# 7                              Abyssal Shard   2.67     10-19
# 8                                  Souleater   1.10     20-29
# 9               Ghastly Adamantite Protector   3.58     30-39

# %%
#Total of players by gender
gender_count = sn_duplicate_df['Gender'].value_counts().to_frame()
gender_count
# Out:
#                        Gender
# Male                      484
# Female                     81
# Other / Non-Disclosed      11

# %%
#Player Gender Percentages
gender_percent = ((sn_duplicate_df.groupby('Gender').size()/sn_duplicate_df['Gender'].count())*100).to_frame()

gender_percent.round(2)
# Out:
#                            0
# Gender
# Female                 14.06
# Male                   84.03
# Other / Non-Disclosed   1.91

# %%
#Summary table
new_df = pd.concat([gender_count,gender_percent.round(2)], axis=1)
new_df.columns = ['Total Count', 'Percent']
new_df
# Out:
#                        Total Count  Percent
# Male                           484    84.03
# Female                          81    14.06
# Other / Non-Disclosed           11     1.91

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#purchase count by gender
purchase_count_gender = purchase_data.groupby(['Gender']).size().reset_index(name='counts').count

purchase_count_gender
# Out:
# <bound method DataFrame.count of                   Gender  counts
# 0                 Female     113
# 1                   Male     652
# 2  Other / Non-Disclosed      15>

# %%
#average purchase price by gender
avg_gender = purchase_data.groupby(['Gender']).mean()
avg_gender.round(2)
new_avg_gender = avg_gender.drop(columns=['Purchase ID', 'Age', 'Item ID'])

new_avg_gender
# Out:
#                           Price
# Gender
# Female                 3.203009
# Male                   3.017853
# Other / Non-Disclosed  3.346000

# %%
#total purchase value by gender
sum_gender = purchase_data.groupby(['Gender']).sum()
sum_gender.round(2)
new_sum_gender = sum_gender.drop(columns=['Purchase ID', 'Age', 'Item ID'])

new_sum_gender
# Out:
#                          Price
# Gender
# Female                  361.94
# Male                   1967.64
# Other / Non-Disclosed    50.19

# %%
#average purchase amount per person
avg_purchase_gender = purchase_data.groupby('Gender', as_index=False).Price.mean()

new_avg_purchase_gender = avg_purchase_gender.round(2)

new_avg_purchase_gender
# Out:
#                   Gender  Price
# 0                 Female   3.20
# 1                   Male   3.02
# 2  Other / Non-Disclosed   3.35

# %%
#summary table
purchase_sum_gen_df_one = pd.concat([new_avg_gender, new_sum_gender], axis=1)
purchase_sum_gen_df_one.columns = ['Average', 'Total']
purchase_sum_gen_df_one
# Out:
#                         Average    Total
# Gender
# Female                 3.203009   361.94
# Male                   3.017853  1967.64
# Other / Non-Disclosed  3.346000    50.19

# %% [markdown]
# Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
#establish bins for ages
print(purchase_data["Age"].max())
print(purchase_data["Age"].min())

# %%
bins = [0, 10,20,30,40,50]
group_labels = ["0-9", "10-19", "20-29", "30-39", "40-49"]

# %%
#categorize players by ages using pd.cut
pd.cut(purchase_data["Age"], bins, labels=group_labels).head()
# Out:
# 0    10-19
# 1    30-39
# 2    20-29
# 3    20-29
# 4    20-29
# Name: Age, dtype: category
# Categories (5, object): ['0-9' < '10-19' < '20-29' < '30-39' < '40-49']

# %%
purchase_data["Age Group"] = pd.cut(purchase_data["Age"], bins, labels=group_labels)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age Group
# 0  Extraction, Quickblade Of Trembling Hands   3.53     10-19
# 1                          Frenzied Scimitar   1.56     30-39
# 2                               Final Critic   4.88     20-29
# 3                                Blindscythe   3.27     20-29
# 4                                       Fury   1.44     20-29

# %%
age_group = purchase_data.groupby("Age Group")
age_group_df = age_group["Age"].count().to_frame()
age_group_df
# Out:
#            Age
# Age Group
# 0-9         32
# 10-19      254
# 20-29      402
# 30-39       85
# 40-49        7

# %%
age_percent_df= ((purchase_data.groupby('Age Group').size()/purchase_data['Age'].count())*100).to_frame()
age_percent_df.round(2)
# Out:
#                0
# Age Group
# 0-9         4.10
# 10-19      32.56
# 20-29      51.54
# 30-39      10.90
# 40-49       0.90

# %%
#Summary

new_age_df = pd.concat([age_group_df,age_percent_df.round(2)], axis=1)
new_age_df.columns = ['Total Count', 'Percent']
new_age_df
# Out:
#            Total Count  Percent
# Age Group
# 0-9                 32     4.10
# 10-19              254    32.56
# 20-29              402    51.54
# 30-39               85    10.90
# 40-49                7     0.90

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
bins = [0, 10,20,30,40,50]
group_labels = ["0-9", "10-19", "20-29", "30-39", "40-49"]

# %%
#categorize players by ages using pd.cut
pd.cut(purchase_data["Age"], bins, labels=group_labels).head()
# Out:
# 0    10-19
# 1    30-39
# 2    20-29
# 3    20-29
# 4    20-29
# Name: Age, dtype: category
# Categories (5, object): ['0-9' < '10-19' < '20-29' < '30-39' < '40-49']

# %%
purchase_data["Age Group"] = pd.cut(purchase_data["Age"], bins, labels=group_labels)
purchase_data.head(10)
# Out:
#    Purchase ID             SN  Age                 Gender  Item ID  \
# 0            0        Lisim78   20                   Male      108
# 1            1    Lisovynya38   40                   Male      143
# 2            2     Ithergue48   24                   Male       92
# 3            3  Chamassasya86   24                   Male      100
# 4            4      Iskosia90   23                   Male      131
# 5            5        Yalae81   22                   Male       81
# 6            6      Itheria73   36                   Male      169
# 7            7    Iskjaskst81   20                   Male      162
# 8            8      Undjask33   22                   Male       21
# 9            9    Chanosian48   35  Other / Non-Disclosed      136
#
#                                    Item Name  Price Age Group
# 0  Extraction, Quickblade Of Trembling Hands   3.53     10-19
# 1                          Frenzied Scimitar   1.56     30-39
# 2                               Final Critic   4.88     20-29
# 3                                Blindscythe   3.27     20-29
# 4                                       Fury   1.44     20-29
# 5                                  Dreamkiss   3.61     20-29
# 6     Interrogator, Blood Blade of the Queen   2.18     30-39
# 7                              Abyssal Shard   2.67     10-19
# 8                                  Souleater   1.10     20-29
# 9               Ghastly Adamantite Protector   3.58     30-39

# %%
#purchase count
purchase_count_age = purchase_data.groupby(['Age Group']).size().reset_index(name='counts').count

purchase_count_age
# Out:
# <bound method DataFrame.count of   Age Group  counts
# 0       0-9      32
# 1     10-19     254
# 2     20-29     402
# 3     30-39      85
# 4     40-49       7>

# %%
#average purchase price
avg_pur_age = purchase_data.groupby(['Age Group']).mean()
avg_pur_age.round(2)
avg_pur_age = avg_pur_age.drop(columns=['Purchase ID', 'Age', 'Item ID'])

avg_pur_age
# Out:
#               Price
# Age Group
# 0-9        3.405000
# 10-19      3.063622
# 20-29      2.992687
# 30-39      3.153647
# 40-49      3.075714

# %%
#total purchase sum

sum_age = purchase_data.groupby(['Age Group']).sum()
sum_age.round(2)
sum_age = sum_age.drop(columns=['Purchase ID', 'Age', 'Item ID'])

sum_age
# Out:
#              Price
# Age Group
# 0-9         108.96
# 10-19       778.16
# 20-29      1203.06
# 30-39       268.06
# 40-49        21.53

# %%
#avg purchase per person

avg_purchase_age = purchase_data.groupby('Age Group', as_index=False).Price.mean()



avg_purchase_age
# Out:
#   Age Group     Price
# 0       0-9  3.405000
# 1     10-19  3.063622
# 2     20-29  2.992687
# 3     30-39  3.153647
# 4     40-49  3.075714

# %%
#summary table

summary_age = pd.join(avg_purchase_age, sum_age, avg_pur_age, on="Age Group")
summary_age
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-241-de243c93b8bd> in <module>
#       1 #summary table
#       2
# ----> 3 summary_age = pd.join(avg_purchase_age, sum_age, avg_pur_age, on="Age Group")
#       4 summary_age
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'join'

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#Purchase count

reduced_purchase_data['Count'] = reduced_purchase_data.groupby(['Item ID', 'Item Name'])['Price'].transform('count')
purchase_data['Spender_Count'].head(10)
# Out:
# 0    3
# 1    1
# 2    1
# 3    1
# 4    1
# 5    2
# 6    1
# 7    2
# 8    1
# 9    2
# Name: Spender_Count, dtype: int64

# %%
#Average purchase price
purchase_data['Spender_Mean'] = purchase_data.groupby(['SN'])['Price'].transform('mean')

purchase_data['Spender_Mean'].head(10)
# Out:
# 0    3.340
# 1    1.560
# 2    4.880
# 3    3.270
# 4    1.440
# 5    3.345
# 6    2.180
# 7    2.210
# 8    1.100
# 9    3.760
# Name: Spender_Mean, dtype: float64

# %%
#Total purchase value
purchase_data['Spender_Total'] = purchase_data.groupby(['SN'])['Price'].transform('sum')

purchase_data['Spender_Total'].head(10)
# Out:
# 0    10.02
# 1     1.56
# 2     4.88
# 3     3.27
# 4     1.44
# 5     6.69
# 6     2.18
# 7     4.42
# 8     1.10
# 9     7.52
# Name: Spender_Total, dtype: float64

# %%
#Summary table

purchase_data["Spender_Count"] = purchase_data['Spender_Count'].astype(float)
purchase_data["Spender_Mean"] = purchase_data['Spender_Mean']
purchase_data["Spender_Total"] = purchase_data['Spender_Total']


purchase_data.head(5)
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age Group  Count  Mean  \
# 0  Extraction, Quickblade Of Trembling Hands   3.53     10-19      3  3.34
# 1                          Frenzied Scimitar   1.56     30-39      1  1.56
# 2                               Final Critic   4.88     20-29      1  4.88
# 3                                Blindscythe   3.27     20-29      1  3.27
# 4                                       Fury   1.44     20-29      1  1.44
#
#    Total  Spender_Count  Spender_Mean  Spender_Total
# 0  10.02            3.0          3.34          10.02
# 1   1.56            1.0          1.56           1.56
# 2   4.88            1.0          4.88           4.88
# 3   3.27            1.0          3.27           3.27
# 4   1.44            1.0          1.44           1.44

# %%
purchase_data = purchase_data.dropna(how='any')

purchase_data.head(5)
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age Group  Count  Mean  \
# 0  Extraction, Quickblade Of Trembling Hands   3.53     10-19      3  3.34
# 1                          Frenzied Scimitar   1.56     30-39      1  1.56
# 2                               Final Critic   4.88     20-29      1  4.88
# 3                                Blindscythe   3.27     20-29      1  3.27
# 4                                       Fury   1.44     20-29      1  1.44
#
#    Total  Spender_Count  Spender_Mean  Spender_Total
# 0  10.02            3.0          3.34          10.02
# 1   1.56            1.0          1.56           1.56
# 2   4.88            1.0          4.88           4.88
# 3   3.27            1.0          3.27           3.27
# 4   1.44            1.0          1.44           1.44

# %%
sorted_SN_df = purchase_data.sort_values(['Spender_Count'], ascending=[False])


sorted_SN_df.head(5)
# Out:
#      Purchase ID         SN  Age Gender  Item ID  \
# 224          224  Lisosia93   25   Male      157
# 603          603  Lisosia93   25   Male      132
# 120          120  Lisosia93   25   Male       24
# 74            74  Lisosia93   25   Male       89
# 609          609  Lisosia93   25   Male       40
#
#                              Item Name  Price Age Group  Count   Mean  Total  \
# 224            Spada, Etcher of Hatred   4.80     20-29      5  3.792  18.96
# 603                         Persuasion   3.19     20-29      5  3.792  18.96
# 120                      Warped Fetish   3.81     20-29      5  3.792  18.96
# 74   Blazefury, Protector of Delusions   4.64     20-29      5  3.792  18.96
# 609                      Second Chance   2.52     20-29      5  3.792  18.96
#
#      Spender_Count  Spender_Mean  Spender_Total
# 224            5.0         3.792          18.96
# 603            5.0         3.792          18.96
# 120            5.0         3.792          18.96
# 74             5.0         3.792          18.96
# 609            5.0         3.792          18.96

# %%
drop_SN_df = sorted_SN_df.drop_duplicates(subset=['SN'])

drop_SN_df.head(5)
# Out:
#      Purchase ID           SN  Age  Gender  Item ID  \
# 224          224    Lisosia93   25    Male      157
# 676          676  Idastidru52   24    Male      111
# 623          623       Iral74   21    Male      114
# 276          276    Tyidaim51   16  Female        9
# 312          312  Strithenu87   20    Male      147
#
#                              Item Name  Price Age Group  Count      Mean  \
# 224            Spada, Etcher of Hatred   4.80     20-29      5  3.792000
# 676                       Misery's End   4.89     20-29      4  3.862500
# 623                 Yearning Mageblade   3.82     20-29      4  3.405000
# 276  Thorn, Conqueror of the Corrupted   2.73     10-19      3  3.943333
# 312  Hellreaver, Heirloom of Inception   4.93     10-19      3  3.393333
#
#      Total  Spender_Count  Spender_Mean  Spender_Total
# 224  18.96            5.0      3.792000          18.96
# 676  15.45            4.0      3.862500          15.45
# 623  13.62            4.0      3.405000          13.62
# 276  11.83            3.0      3.943333          11.83
# 312  10.18            3.0      3.393333          10.18

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
reduced_purchase_data = purchase_data.loc[:, ["Item ID", "Item Name", "Price"]]
reduced_purchase_data.head(10)
# Out:
#    Item ID                                  Item Name  Price
# 0      108  Extraction, Quickblade Of Trembling Hands   3.53
# 1      143                          Frenzied Scimitar   1.56
# 2       92                               Final Critic   4.88
# 3      100                                Blindscythe   3.27
# 4      131                                       Fury   1.44
# 5       81                                  Dreamkiss   3.61
# 6      169     Interrogator, Blood Blade of the Queen   2.18
# 7      162                              Abyssal Shard   2.67
# 8       21                                  Souleater   1.10
# 9      136               Ghastly Adamantite Protector   3.58

# %%
reduced_purchase_data['Total'] = reduced_purchase_data.groupby(['Item ID', 'Item Name'])['Price'].transform('sum')
reduced_purchase_data['Total'].head(10)
# Out:
# 0    31.77
# 1     9.36
# 2    59.99
# 3    16.35
# 4     7.20
# 5     7.22
# 6     8.72
# 7    13.35
# 8     5.50
# 9    21.48
# Name: Total, dtype: float64

# %%
reduced_purchase_data['Average'] = reduced_purchase_data.groupby(['Item ID', 'Item Name'])['Price'].transform('mean')
reduced_purchase_data['Average'].head(10)
# Out:
# 0    3.530000
# 1    1.560000
# 2    4.614615
# 3    3.270000
# 4    1.440000
# 5    3.610000
# 6    2.180000
# 7    2.670000
# 8    1.100000
# 9    3.580000
# Name: Average, dtype: float64

# %%
reduced_purchase_data['Count'] = reduced_purchase_data.groupby(['Item ID', 'Item Name'])['Price'].transform('count')
reduced_purchase_data['Count'].head(10)
# Out:
# 0     9
# 1     6
# 2    13
# 3     5
# 4     5
# 5     2
# 6     4
# 7     5
# 8     5
# 9     6
# Name: Count, dtype: int64

# %%
reduced_purchase_data["Count"] = reduced_purchase_data['Count'].astype(float)
reduced_purchase_data["Average"] = reduced_purchase_data['Average']
reduced_purchase_data["Total"] = reduced_purchase_data['Total']


reduced_purchase_data.head(10)
# Out:
#    Item ID                                  Item Name  Price  Total   Average  \
# 0      108  Extraction, Quickblade Of Trembling Hands   3.53  31.77  3.530000
# 1      143                          Frenzied Scimitar   1.56   9.36  1.560000
# 2       92                               Final Critic   4.88  59.99  4.614615
# 3      100                                Blindscythe   3.27  16.35  3.270000
# 4      131                                       Fury   1.44   7.20  1.440000
# 5       81                                  Dreamkiss   3.61   7.22  3.610000
# 6      169     Interrogator, Blood Blade of the Queen   2.18   8.72  2.180000
# 7      162                              Abyssal Shard   2.67  13.35  2.670000
# 8       21                                  Souleater   1.10   5.50  1.100000
# 9      136               Ghastly Adamantite Protector   3.58  21.48  3.580000
#
#    Count
# 0    9.0
# 1    6.0
# 2   13.0
# 3    5.0
# 4    5.0
# 5    2.0
# 6    4.0
# 7    5.0
# 8    5.0
# 9    6.0

# %%
more_reduced_purchase_data = reduced_purchase_data.dropna(how='any')

more_reduced_purchase_data
# Out:
#      Item ID                                  Item Name  Price  Total  \
# 0        108  Extraction, Quickblade Of Trembling Hands   3.53  31.77
# 1        143                          Frenzied Scimitar   1.56   9.36
# 2         92                               Final Critic   4.88  59.99
# 3        100                                Blindscythe   3.27  16.35
# 4        131                                       Fury   1.44   7.20
# ..       ...                                        ...    ...    ...
# 775       60                                       Wolf   3.54  28.32
# 776      164                           Exiled Doomblade   1.63  11.41
# 777       67      Celeste, Incarnation of the Corrupted   3.46  13.84
# 778       92                               Final Critic   4.19  59.99
# 779       50                                       Dawn   4.60  18.40
#
#       Average  Count
# 0    3.530000    9.0
# 1    1.560000    6.0
# 2    4.614615   13.0
# 3    3.270000    5.0
# 4    1.440000    5.0
# ..        ...    ...
# 775  3.540000    8.0
# 776  1.630000    7.0
# 777  3.460000    4.0
# 778  4.614615   13.0
# 779  4.600000    4.0
#
# [780 rows x 6 columns]

# %%
sorted_df = reduced_purchase_data.sort_values(['Count'], ascending=[False])


sorted_df.head(10)
# Out:
#      Item ID     Item Name  Price  Total   Average  Count
# 722       92  Final Critic   4.88  59.99  4.614615   13.0
# 536       92  Final Critic   4.19  59.99  4.614615   13.0
# 99        92  Final Critic   4.19  59.99  4.614615   13.0
# 273       92  Final Critic   4.88  59.99  4.614615   13.0
# 277       92  Final Critic   4.88  59.99  4.614615   13.0
# 712       92  Final Critic   4.88  59.99  4.614615   13.0
# 768       92  Final Critic   4.88  59.99  4.614615   13.0
# 767       92  Final Critic   4.88  59.99  4.614615   13.0
# 411       92  Final Critic   4.19  59.99  4.614615   13.0
# 774       92  Final Critic   4.19  59.99  4.614615   13.0

# %%
drop_df = sorted_df.drop_duplicates(subset=['Item Name'])

drop_df.head(10)
# Out:
#      Item ID                                     Item Name  Price  Total  \
# 722       92                                  Final Critic   4.88  59.99
# 62       178  Oathbreaker, Last Hope of the Breaking Storm   4.23  50.76
# 504       82                                       Nirvana   4.90  44.10
# 56       108     Extraction, Quickblade Of Trembling Hands   3.53  31.77
# 538      132                                    Persuasion   3.19  28.99
# 474      145                          Fiery Glass Crusader   4.58  41.22
# 322       37           Shadow Strike, Glory of Ending Hope   3.16  25.28
# 685       34                               Retribution Axe   2.22  17.76
# 709       75                       Brutality Ivory Warmace   2.42  19.36
# 344       19                 Pursuit, Cudgel of Necromancy   1.02   8.16
#
#       Average  Count
# 722  4.614615   13.0
# 62   4.230000   12.0
# 504  4.900000    9.0
# 56   3.530000    9.0
# 538  3.221111    9.0
# 474  4.580000    9.0
# 322  3.160000    8.0
# 685  2.220000    8.0
# 709  2.420000    8.0
# 344  1.020000    8.0

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
profit_df = drop_df.sort_values(['Total'], ascending=[False])

profit_df.head(10)
# Out:
#      Item ID                                     Item Name  Price  Total  \
# 722       92                                  Final Critic   4.88  59.99
# 62       178  Oathbreaker, Last Hope of the Breaking Storm   4.23  50.76
# 504       82                                       Nirvana   4.90  44.10
# 474      145                          Fiery Glass Crusader   4.58  41.22
# 714      103                                Singed Scalpel   4.35  34.80
# 179       59                 Lightning, Etcher of the King   4.23  33.84
# 56       108     Extraction, Quickblade Of Trembling Hands   3.53  31.77
# 692       78                    Glimmer, Ender of the Moon   4.40  30.80
# 259       72                                 Winter's Bite   3.77  30.16
# 538      132                                    Persuasion   3.19  28.99
#
#       Average  Count
# 722  4.614615   13.0
# 62   4.230000   12.0
# 504  4.900000    9.0
# 474  4.580000    9.0
# 714  4.350000    8.0
# 179  4.230000    8.0
# 56   3.530000    9.0
# 692  4.400000    7.0
# 259  3.770000    8.0
# 538  3.221111    9.0
